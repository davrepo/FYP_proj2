# %%
import csv
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from scipy.stats import sem
import pandas as pd

from sklearn.preprocessing import MinMaxScaler

# import PCA
from sklearn.decomposition import PCA

# %% [markdown]
# normalized data into feature_normalized.csv

# %%
from sklearn.preprocessing import MinMaxScaler

# Load the dataset
df = pd.read_csv('feature_output.csv')

# Features to be normalized
cols_to_norm = ['asymmetry_1', 'asymmetry_2', 'border_irregularity', 'color_asymmetry_1', 
                'color_asymmetry_2', 'texture_contrast', 'texture_dissemilarity']

# Apply Min-Max normalization
scaler = MinMaxScaler()
df[cols_to_norm] = scaler.fit_transform(df[cols_to_norm])

# Save the normalized data
df.to_csv('feature_output_normalized.csv', index=False)

# %% [markdown]
# Visualize the difference between MEL and SEK in terms of features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data from the CSV file
df = pd.read_csv('feature_output_normalized.csv')

# Replace the diagnosis codes with the actual diagnosis names for clearer visualization
df['diagnostic'] = df['diagnostic'].replace({0: 'NOT', 1: 'MEL'})

# List all features excluding 'smoke' and 'itch'
features = ['asymmetry_1', 'asymmetry_2', 'border_irregularity', 'color_asymmetry_1', 'color_asymmetry_2', 'texture_contrast', 'texture_dissemilarity']

# Create a boxplot for each feature
for feature in features:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x='diagnostic', y=feature, data=df)
    plt.title('Boxplot of ' + feature + ' by Diagnosis')
    plt.show()
